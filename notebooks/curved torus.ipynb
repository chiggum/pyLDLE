# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle/curvedtorus/'

# %%
X, labelsMat, ddX = datasets.Datasets().curvedtorus3d()
# Out:
# X.shape =  (10000, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=10, max_iter0=80,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'colorcube', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 2500 points processed...
# A_k, Atilde_k: 5000 points processed...
# A_k, Atilde_k: 7500 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 2500 points processed...
# local_param: 5000 points processed...
# local_param: 7500 points processed...
# local_param: all 10000 points processed...
# After iter 1, max distortion is 22.834300
# After iter 2, max distortion is 21.759810
# After iter 3, max distortion is 21.759810
# After iter 4, max distortion is 21.759810
# After iter 5, max distortion is 21.759810
# After iter 6, max distortion is 21.759810
# After iter 7, max distortion is 21.759810
# After iter 8, max distortion is 21.759810
# Max local distortion = 21.759810007815005
# ###############
# Took 73.1 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 10000
# #nodes in views with sz < 2 = 10000
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 851
# #nodes in views with sz < 3 = 1702
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 523
# #nodes in views with sz < 4 = 1569
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 320
# #nodes in views with sz < 5 = 1280
# Remaining #nodes in views with sz < 5 = 0
# # non-empty views with sz < 6 = 237
# #nodes in views with sz < 6 = 1185
# Remaining #nodes in views with sz < 6 = 0
# # non-empty views with sz < 7 = 156
# #nodes in views with sz < 7 = 936
# Remaining #nodes in views with sz < 7 = 0
# # non-empty views with sz < 8 = 127
# #nodes in views with sz < 8 = 889
# Remaining #nodes in views with sz < 8 = 0
# # non-empty views with sz < 9 = 97
# #nodes in views with sz < 9 = 776
# Remaining #nodes in views with sz < 9 = 0
# # non-empty views with sz < 10 = 74
# #nodes in views with sz < 10 = 666
# Remaining #nodes in views with sz < 10 = 0
# After clustering, max distortion is 38.482520
# ###############
# Took 85.8 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 155 intermediate views
# Ambiguous overlaps checked for 310 intermediate views
# Ambiguous overlaps checked for 465 intermediate views
# Ambiguous overlaps checked for 620 intermediate views
# Ambiguous overlaps checked for 623 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 155 views completed
# Initial alignment of 310 views completed
# Initial alignment of 465 views completed
# Initial alignment of 620 views completed
# error: 0.002573423435378305
# ###############
# Took 9.8 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.0011501127997471268
# Iteration: 1
# error: 0.0011838761688479481
# Iteration: 2
# error: 0.0011113538970678463
# Iteration: 3
# error: 0.0011067872224577182
# Iteration: 4
# error: 0.0011338670555574304
# Iteration: 5
# error: 0.001169116821727225
# Iteration: 6
# error: 0.001182089190138605
# Iteration: 7
# error: 0.001196937248208452
# Iteration: 8
# error: 0.00119772919862057
# Iteration: 9
# error: 0.0012040115710361546
# Iteration: 10
# error: 0.001211806133742665
# Iteration: 11
# error: 0.001210675639302957
# Iteration: 12
# error: 0.0012075928639671528
# Iteration: 13
# error: 0.0012082519718871543
# Iteration: 14
# error: 0.0012054691279731538
# Iteration: 15
# error: 0.0012026005331373683
# Iteration: 16
# error: 0.001199622388422038
# Iteration: 17
# error: 0.0011969236113088142
# Iteration: 18
# error: 0.0011952718818473344
# Iteration: 19
# error: 0.001192381007859463
# Iteration: 20
# error: 0.0011898736415657403
# Iteration: 21
# error: 0.0011872714388957582
# Iteration: 22
# error: 0.0011846648303679166
# Iteration: 23
# error: 0.001181976799301049
# Iteration: 24
# error: 0.0011936846966028047
# Iteration: 25
# error: 0.001198871566070496
# Iteration: 26
# error: 0.0011988038245771548
# Iteration: 27
# error: 0.0012039387768056392
# Iteration: 28
# error: 0.0012026352745572462
# Iteration: 29
# error: 0.0012013692432333003
# Iteration: 30
# error: 0.0011995742841059821
# Iteration: 31
# error: 0.0012137636592184041
# Iteration: 32
# error: 0.0012134823473853164
# Iteration: 33
# error: 0.0012235482370904255
# Iteration: 34
# error: 0.0012241945969033944
# Iteration: 35
# error: 0.0012248648267884955
# Iteration: 36
# error: 0.0012238243896423885
# Iteration: 37
# error: 0.0012223569421916688
# Iteration: 38
# error: 0.0012209031083097142
# Iteration: 39
# error: 0.001219205606310826
# Iteration: 40
# error: 0.001217548940850458
# Iteration: 41
# error: 0.0012159213562952151
# Iteration: 42
# error: 0.0012143962431332002
# Iteration: 43
# error: 0.0012128770151644782
# Iteration: 44
# error: 0.0012111583474901796
# Iteration: 45
# error: 0.0012100328927400822
# Iteration: 46
# error: 0.0012084358877882857
# Iteration: 47
# error: 0.0012067647878482243
# Iteration: 48
# error: 0.0012054733151597283
# Iteration: 49
# error: 0.0012042354816415419
# Iteration: 50
# error: 0.0012028790860522712
# Iteration: 51
# error: 0.0012016602715153308
# Iteration: 52
# error: 0.0012005199973014818
# Iteration: 53
# error: 0.001199299178174089
# Iteration: 54
# error: 0.0011983371176970904
# Iteration: 55
# error: 0.0011973425078802208
# Iteration: 56
# error: 0.0011961572792151226
# Iteration: 57
# error: 0.0011954092368150586
# Iteration: 58
# error: 0.0011944238695674285
# Iteration: 59
# error: 0.0011936162153349682
# Iteration: 60
# error: 0.0011927164967900138
# Iteration: 61
# error: 0.0011918821032343742
# Iteration: 62
# error: 0.0011913222226030977
# Iteration: 63
# error: 0.0011904392995724725
# Iteration: 64
# error: 0.001189779505304156
# Iteration: 65
# error: 0.0011890822919378404
# Iteration: 66
# error: 0.0011884856157216544
# Iteration: 67
# error: 0.001187908673229192
# Iteration: 68
# error: 0.0011873228637609813
# Iteration: 69
# error: 0.0011867029795690977
# Iteration: 70
# error: 0.0011862629907724003
# Iteration: 71
# error: 0.001185640025586353
# Iteration: 72
# error: 0.0011851726357482802
# Iteration: 73
# error: 0.001184641707920928
# Iteration: 74
# error: 0.0011842045104205814
# Iteration: 75
# error: 0.0011835936437749389
# Iteration: 76
# error: 0.0011831756771935565
# Iteration: 77
# error: 0.0011829047669322944
# Iteration: 78
# error: 0.0011825228519350402
# Iteration: 79
# error: 0.0011820550700127515
# ###############
# Took 1161.7 seconds to refine global embedding.
# ###############
# ###############
# Took 1173.6 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)

# %%
vis = visualize.Visualize(save_dir_root)
vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'summer',
                     ldle_obj.color_of_pts_on_tear_final, 'colorcube', 'LDLE_colorcube',
                     figsize=(10,10), s=80)

# %% [markdown]
# # LTSA

# %%
from sklearn.manifold import LocallyLinearEmbedding
import visualize
vis = visualize.Visualize(save_dir_root)

# %%
ltsa_obj = LocallyLinearEmbedding(method='ltsa', n_neighbors=25, n_components=2, n_jobs=-1, random_state=42)

# %%
y_ltsa = ltsa_obj.fit_transform(X)

# %%
vis.global_embedding(y_ltsa, labelsMat[:,0], 'hsv', title='LTSA')

# %% [markdown]
# # UMAP

# %%
from umap import UMAP
import visualize
vis = visualize.Visualize(save_dir_root)

# %%
umap_obj = UMAP(n_neighbors=200, min_dist=0.5, n_components=2,
                random_state=42, n_epochs=500, metric='euclidean')

# %%
y_umap = umap_obj.fit_transform(X)

# %%
vis.global_embedding(y_umap, labelsMat[:,0], 'hsv', title='UMAP')

# %% [markdown]
# # t-SNE

# %%
from sklearn.manifold import TSNE
import visualize
vis = visualize.Visualize(save_dir_root)

# %%
tsne_obj = TSNE(perplexity=50, early_exaggeration=6, n_components=2,
                metric='euclidean', random_state=42, n_iter=1000,
                n_jobs=-1, init='random')

# %%
y_tsne = tsne_obj.fit_transform(X)

# %%
vis.global_embedding(y_tsne, labelsMat[:,0], 'hsv', title='t-SNE')
