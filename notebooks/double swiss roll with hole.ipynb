# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle1/double_swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=5, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 528
# Doubled manifold
# Using LDLE_1
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4841 points processed...
# A_k, Atilde_k: 9682 points processed...
# A_k, Atilde_k: 14523 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4841 points processed...
# local_param: 9682 points processed...
# local_param: 14523 points processed...
# local_param: all 19364 points processed...
# After iter 1, max distortion is 8.227021
# After iter 2, max distortion is 7.768157
# After iter 3, max distortion is 7.768157
# After iter 4, max distortion is 7.768157
# After iter 5, max distortion is 7.768157
# After iter 6, max distortion is 7.768157
# After iter 7, max distortion is 7.768157
# After iter 8, max distortion is 7.768157
# After iter 9, max distortion is 7.768157
# After iter 10, max distortion is 7.768157
# After iter 11, max distortion is 7.768157
# Max local distortion = 7.768157377573345
# ###############
# Took 213.1 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 469
# #nodes in views with sz < 3 = 938
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 418
# #nodes in views with sz < 4 = 1254
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 265
# #nodes in views with sz < 5 = 1060
# Remaining #nodes in views with sz < 5 = 0
# After clustering, max distortion is 8.136764
# ###############
# Took 46.3 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 287 intermediate views
# Ambiguous overlaps checked for 574 intermediate views
# Ambiguous overlaps checked for 861 intermediate views
# Ambiguous overlaps checked for 1148 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 287 views completed
# Initial alignment of 574 views completed
# Initial alignment of 861 views completed
# error: 0.0008258052333989921
# ###############
# Took 14.8 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.0002958891819228124
# Iteration: 1
# error: 0.00025530323107466566
# Iteration: 2
# error: 0.00024167313067996774
# Iteration: 3
# error: 0.00023504690777790074
# Iteration: 4
# error: 0.00023095130435818166
# Iteration: 5
# error: 0.00022806786912205336
# Iteration: 6
# error: 0.00022607412828654162
# Iteration: 7
# error: 0.00022443569866200628
# Iteration: 8
# error: 0.00022309329572424164
# Iteration: 9
# error: 0.00022198000313384216
# Iteration: 10
# error: 0.00022101907832716648
# Iteration: 11
# error: 0.00022014568313513937
# Iteration: 12
# error: 0.00021936175550154867
# Iteration: 13
# error: 0.00021863842167968328
# Iteration: 14
# error: 0.00021799221093290097
# Iteration: 15
# error: 0.00021741516336809262
# Iteration: 16
# error: 0.00021681225818057258
# Iteration: 17
# error: 0.0002162486963747748
# Iteration: 18
# error: 0.00021574936829433985
# Iteration: 19
# error: 0.00021526147295475228
# ###############
# Took 625.9 seconds to refine global embedding.
# ###############
# ###############
# Took 645.4 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'jet', title='LDLE0')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'jet', title='LDLE1')
