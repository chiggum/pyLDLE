# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle/double_swissrollwithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().swissrollwithhole()
# Out:
# X.shape =  (9946, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=5, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 528
# Doubled manifold
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4841 points processed...
# A_k, Atilde_k: 9682 points processed...
# A_k, Atilde_k: 14523 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4841 points processed...
# local_param: 9682 points processed...
# local_param: 14523 points processed...
# local_param: all 19364 points processed...
# After iter 1, max distortion is 8.834140
# After iter 2, max distortion is 8.341307
# After iter 3, max distortion is 8.341307
# After iter 4, max distortion is 8.341307
# After iter 5, max distortion is 8.341307
# After iter 6, max distortion is 8.341307
# After iter 7, max distortion is 8.341307
# After iter 8, max distortion is 8.341307
# After iter 9, max distortion is 8.341307
# After iter 10, max distortion is 8.341307
# After iter 11, max distortion is 8.341307
# Max local distortion = 8.34130700192867
# ###############
# Took 292.6 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9946
# #nodes in views with sz < 2 = 9946
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 471
# #nodes in views with sz < 3 = 942
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 463
# #nodes in views with sz < 4 = 1389
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 227
# #nodes in views with sz < 5 = 908
# Remaining #nodes in views with sz < 5 = 0
# After clustering, max distortion is 8.223389
# ###############
# Took 64.9 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 292 intermediate views
# Ambiguous overlaps checked for 584 intermediate views
# Ambiguous overlaps checked for 876 intermediate views
# Ambiguous overlaps checked for 1168 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 292 views completed
# Initial alignment of 584 views completed
# Initial alignment of 876 views completed
# error: 0.001322098235254695
# ###############
# Took 22.3 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.0004895257075151424
# Iteration: 1
# error: 0.0004257080241802244
# Iteration: 2
# error: 0.0004029515479987359
# Iteration: 3
# error: 0.0003920340138277368
# Iteration: 4
# error: 0.0003858562974015118
# Iteration: 5
# error: 0.0003818949571951536
# Iteration: 6
# error: 0.00037924925027146047
# Iteration: 7
# error: 0.0003773476258671422
# Iteration: 8
# error: 0.00037572196482335676
# Iteration: 9
# error: 0.0003744045366935027
# Iteration: 10
# error: 0.000373330097841508
# Iteration: 11
# error: 0.0003725359744592842
# Iteration: 12
# error: 0.0003717428050750058
# Iteration: 13
# error: 0.00037113119386260026
# Iteration: 14
# error: 0.00037052274754806867
# Iteration: 15
# error: 0.0003700115337889912
# Iteration: 16
# error: 0.0003695491184512793
# Iteration: 17
# error: 0.00036912587936622
# Iteration: 18
# error: 0.00036877537278441077
# Iteration: 19
# error: 0.0003684403994635866
# ###############
# Took 656.3 seconds to refine global embedding.
# ###############
# ###############
# Took 684.9 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)
