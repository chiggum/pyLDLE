# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle1/three_spheres/'

# %%
X, labelsMat, ddX = datasets.Datasets().multi_spheres(m=3,n=3000)
# Out:
# X.shape =  (3000, 3)
# X.shape =  (3000, 3)
# X.shape =  (3000, 3)
# X.shape =  (9000, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=15, max_iter0=30, 
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Using LDLE_1
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 2250 points processed...
# A_k, Atilde_k: 4500 points processed...
# A_k, Atilde_k: 6750 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 2250 points processed...
# local_param: 4500 points processed...
# local_param: 6750 points processed...
# local_param: all 9000 points processed...
# After iter 1, max distortion is 4.503964
# After iter 2, max distortion is 2.764879
# After iter 3, max distortion is 2.385498
# After iter 4, max distortion is 2.071008
# After iter 5, max distortion is 1.989909
# After iter 6, max distortion is 1.791310
# After iter 7, max distortion is 1.769697
# After iter 8, max distortion is 1.769697
# After iter 9, max distortion is 1.769697
# After iter 10, max distortion is 1.769697
# After iter 11, max distortion is 1.769697
# After iter 12, max distortion is 1.769697
# Max local distortion = 1.7696972482571245
# ###############
# Took 53.6 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9000
# #nodes in views with sz < 2 = 9000
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 151
# #nodes in views with sz < 3 = 302
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 167
# #nodes in views with sz < 4 = 501
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 171
# #nodes in views with sz < 5 = 684
# Remaining #nodes in views with sz < 5 = 0
# # non-empty views with sz < 6 = 125
# #nodes in views with sz < 6 = 625
# Remaining #nodes in views with sz < 6 = 0
# # non-empty views with sz < 7 = 82
# #nodes in views with sz < 7 = 492
# Remaining #nodes in views with sz < 7 = 0
# # non-empty views with sz < 8 = 84
# #nodes in views with sz < 8 = 588
# Remaining #nodes in views with sz < 8 = 0
# # non-empty views with sz < 9 = 75
# #nodes in views with sz < 9 = 600
# Remaining #nodes in views with sz < 9 = 0
# # non-empty views with sz < 10 = 70
# #nodes in views with sz < 10 = 630
# Remaining #nodes in views with sz < 10 = 0
# # non-empty views with sz < 11 = 52
# #nodes in views with sz < 11 = 520
# Remaining #nodes in views with sz < 11 = 0
# # non-empty views with sz < 12 = 41
# #nodes in views with sz < 12 = 451
# Remaining #nodes in views with sz < 12 = 0
# # non-empty views with sz < 13 = 35
# #nodes in views with sz < 13 = 420
# Remaining #nodes in views with sz < 13 = 0
# # non-empty views with sz < 14 = 36
# #nodes in views with sz < 14 = 468
# Remaining #nodes in views with sz < 14 = 0
# # non-empty views with sz < 15 = 26
# #nodes in views with sz < 15 = 364
# Remaining #nodes in views with sz < 15 = 0
# After clustering, max distortion is 1.984673
# ###############
# Took 93.0 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 87 intermediate views
# Ambiguous overlaps checked for 174 intermediate views
# Ambiguous overlaps checked for 261 intermediate views
# Ambiguous overlaps checked for 348 intermediate views
# Ambiguous overlaps checked for 350 points
# Seq of intermediate views and their predecessors computed.
# No. of connected components = 3
# Multiple connected components detected
# Initial alignment of 87 views completed
# Initial alignment of 87 views completed
# Initial alignment of 87 views completed
# error: 0.0002869881818961371
# ###############
# Took 4.3 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.00026761044229919336
# Iteration: 1
# error: 0.00039409617169219744
# Iteration: 2
# error: 0.00044792080110342495
# Iteration: 3
# error: 0.0004845548146875023
# Iteration: 4
# error: 0.0005085267534535977
# Iteration: 5
# error: 0.000533345637761129
# Iteration: 6
# error: 0.0005551825380357089
# Iteration: 7
# error: 0.0006034083038304695
# Iteration: 8
# error: 0.000653125974964295
# Iteration: 9
# error: 0.0006843608520157478
# Iteration: 10
# error: 0.0007031069011539171
# Iteration: 11
# error: 0.0007311129137542135
# Iteration: 12
# error: 0.0007725300296279198
# Iteration: 13
# error: 0.0008064283983750095
# Iteration: 14
# error: 0.000827521017778269
# Iteration: 15
# error: 0.000838467667255614
# Iteration: 16
# error: 0.0008473687887836001
# Iteration: 17
# error: 0.0008525875101770425
# Iteration: 18
# error: 0.000855486048000873
# Iteration: 19
# error: 0.0008579195118405379
# Iteration: 20
# error: 0.0008615097411214804
# Iteration: 21
# error: 0.0008639497897413381
# Iteration: 22
# error: 0.000866414880476209
# Iteration: 23
# error: 0.0008685081872026422
# Iteration: 24
# error: 0.000871929188818184
# Iteration: 25
# error: 0.0008739561730675739
# Iteration: 26
# error: 0.0008757553302740395
# Iteration: 27
# error: 0.0008772404758783894
# Iteration: 28
# error: 0.0008785711648832726
# Iteration: 29
# error: 0.0008798557757921859
# ###############
# Took 223.8 seconds to refine global embedding.
# ###############
# ###############
# Took 228.7 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'jet', 'LDLE0_jet')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'jet', 'LDLE1_jet')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'colorcube', 'LDLE0_colorcube')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'colorcube', 'LDLE1_colorcube')
