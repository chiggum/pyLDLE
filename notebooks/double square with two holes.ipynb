# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle/double_squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=10, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 540
# Doubled manifold
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4449 points processed...
# A_k, Atilde_k: 8898 points processed...
# A_k, Atilde_k: 13347 points processed...
# A_k, Atilde_k: 17796 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4449 points processed...
# local_param: 8898 points processed...
# local_param: 13347 points processed...
# local_param: 17796 points processed...
# local_param: all 17798 points processed...
# After iter 1, max distortion is 7.441073
# After iter 2, max distortion is 7.260747
# After iter 3, max distortion is 7.260747
# After iter 4, max distortion is 7.260747
# After iter 5, max distortion is 7.260747
# After iter 6, max distortion is 7.260747
# After iter 7, max distortion is 7.260747
# After iter 8, max distortion is 7.260747
# Max local distortion = 7.2598382423227115
# ###############
# Took 261.3 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 348
# #nodes in views with sz < 3 = 696
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 392
# #nodes in views with sz < 4 = 1176
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 278
# #nodes in views with sz < 5 = 1112
# Remaining #nodes in views with sz < 5 = 0
# # non-empty views with sz < 6 = 188
# #nodes in views with sz < 6 = 940
# Remaining #nodes in views with sz < 6 = 0
# # non-empty views with sz < 7 = 122
# #nodes in views with sz < 7 = 732
# Remaining #nodes in views with sz < 7 = 0
# # non-empty views with sz < 8 = 108
# #nodes in views with sz < 8 = 756
# Remaining #nodes in views with sz < 8 = 0
# # non-empty views with sz < 9 = 97
# #nodes in views with sz < 9 = 776
# Remaining #nodes in views with sz < 9 = 0
# # non-empty views with sz < 10 = 75
# #nodes in views with sz < 10 = 675
# Remaining #nodes in views with sz < 10 = 0
# After clustering, max distortion is 11.319090
# ###############
# Took 83.4 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 143 intermediate views
# Ambiguous overlaps checked for 286 intermediate views
# Ambiguous overlaps checked for 429 intermediate views
# Ambiguous overlaps checked for 572 intermediate views
# Ambiguous overlaps checked for 573 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 143 views completed
# Initial alignment of 286 views completed
# Initial alignment of 429 views completed
# Initial alignment of 572 views completed
# error: 0.0007319882295873854
# ###############
# Took 7.2 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.0002467032739341586
# Iteration: 1
# error: 0.00023174148464049195
# Iteration: 2
# error: 0.0002259900042198261
# Iteration: 3
# error: 0.00022265101955473544
# Iteration: 4
# error: 0.0002203209965562553
# Iteration: 5
# error: 0.00021859724536555882
# Iteration: 6
# error: 0.00021725841682567983
# Iteration: 7
# error: 0.0002161725639510468
# Iteration: 8
# error: 0.00021526030992601624
# Iteration: 9
# error: 0.000214492260323187
# Iteration: 10
# error: 0.0002138320506865827
# Iteration: 11
# error: 0.00021325655383355125
# Iteration: 12
# error: 0.00021277473137408005
# Iteration: 13
# error: 0.00021232978774967938
# Iteration: 14
# error: 0.00021195797368407914
# Iteration: 15
# error: 0.0002116174576676313
# Iteration: 16
# error: 0.00021131509547806814
# Iteration: 17
# error: 0.00021105890871504592
# Iteration: 18
# error: 0.00021081202559312799
# Iteration: 19
# error: 0.00021062036948023692
# ###############
# Took 268.5 seconds to refine global embedding.
# ###############
# ###############
# Took 277.4 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)
