# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle1/double_squarewithtwoholes/'

# %%
X, labelsMat, ddX = datasets.Datasets().squarewithtwoholes()
# Out:
# X.shape =  (9169, 2)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=8, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 540
# Doubled manifold
# Using LDLE_1
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4449 points processed...
# A_k, Atilde_k: 8898 points processed...
# A_k, Atilde_k: 13347 points processed...
# A_k, Atilde_k: 17796 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4449 points processed...
# local_param: 8898 points processed...
# local_param: 13347 points processed...
# local_param: 17796 points processed...
# local_param: all 17798 points processed...
# After iter 1, max distortion is 7.444250
# After iter 2, max distortion is 7.204874
# After iter 3, max distortion is 7.204874
# After iter 4, max distortion is 7.204874
# After iter 5, max distortion is 7.204874
# After iter 6, max distortion is 7.204874
# After iter 7, max distortion is 7.204874
# After iter 8, max distortion is 7.204874
# Max local distortion = 7.2048742866726565
# ###############
# Took 195.4 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9169
# #nodes in views with sz < 2 = 9169
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 315
# #nodes in views with sz < 3 = 630
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 417
# #nodes in views with sz < 4 = 1251
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 259
# #nodes in views with sz < 5 = 1036
# Remaining #nodes in views with sz < 5 = 0
# # non-empty views with sz < 6 = 154
# #nodes in views with sz < 6 = 770
# Remaining #nodes in views with sz < 6 = 0
# # non-empty views with sz < 7 = 157
# #nodes in views with sz < 7 = 942
# Remaining #nodes in views with sz < 7 = 0
# # non-empty views with sz < 8 = 100
# #nodes in views with sz < 8 = 700
# Remaining #nodes in views with sz < 8 = 0
# After clustering, max distortion is 7.478565
# ###############
# Took 52.9 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 181 intermediate views
# Ambiguous overlaps checked for 362 intermediate views
# Ambiguous overlaps checked for 543 intermediate views
# Ambiguous overlaps checked for 724 intermediate views
# Ambiguous overlaps checked for 727 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 181 views completed
# Initial alignment of 362 views completed
# Initial alignment of 543 views completed
# Initial alignment of 724 views completed
# error: 0.0009477835417610345
# ###############
# Took 7.4 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.0003605189074092962
# Iteration: 1
# error: 0.00033667422446065874
# Iteration: 2
# error: 0.0003265926420080392
# Iteration: 3
# error: 0.0003205944955389222
# Iteration: 4
# error: 0.00031625434205969776
# Iteration: 5
# error: 0.00031324154428380885
# Iteration: 6
# error: 0.0003107075578591216
# Iteration: 7
# error: 0.00030858133368679455
# Iteration: 8
# error: 0.00030713943593213365
# Iteration: 9
# error: 0.00030565065048002605
# Iteration: 10
# error: 0.0003044904498604033
# Iteration: 11
# error: 0.0003034360447532613
# Iteration: 12
# error: 0.0003025362166517421
# Iteration: 13
# error: 0.00030169576353465514
# Iteration: 14
# error: 0.0003011579236189721
# Iteration: 15
# error: 0.0003004993992489883
# Iteration: 16
# error: 0.0002999505892502046
# Iteration: 17
# error: 0.0002994946687412299
# Iteration: 18
# error: 0.00029906947719531674
# Iteration: 19
# error: 0.0002986796899521996
# ###############
# Took 302.0 seconds to refine global embedding.
# ###############
# ###############
# Took 311.3 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'jet', title='LDLE0')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'jet', title='LDLE1')
