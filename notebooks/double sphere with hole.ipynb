# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle1/double_spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=10, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 34
# Doubled manifold
# Using LDLE_1
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4957 points processed...
# A_k, Atilde_k: 9914 points processed...
# A_k, Atilde_k: 14871 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4957 points processed...
# local_param: 9914 points processed...
# local_param: 14871 points processed...
# local_param: all 19828 points processed...
# After iter 1, max distortion is 6.663589
# After iter 2, max distortion is 3.516959
# After iter 3, max distortion is 3.516959
# After iter 4, max distortion is 3.516959
# After iter 5, max distortion is 3.516959
# After iter 6, max distortion is 3.516959
# After iter 7, max distortion is 3.516959
# After iter 8, max distortion is 3.516959
# After iter 9, max distortion is 3.516959
# After iter 10, max distortion is 3.516959
# After iter 11, max distortion is 3.516959
# After iter 12, max distortion is 3.516959
# After iter 13, max distortion is 3.516959
# After iter 14, max distortion is 3.516959
# After iter 15, max distortion is 3.516959
# After iter 16, max distortion is 3.516959
# After iter 17, max distortion is 3.516959
# After iter 18, max distortion is 3.516959
# After iter 19, max distortion is 3.516959
# Max local distortion = 3.5169590511427344
# ###############
# Took 173.9 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 373
# #nodes in views with sz < 3 = 746
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 336
# #nodes in views with sz < 4 = 1008
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 232
# #nodes in views with sz < 5 = 928
# Remaining #nodes in views with sz < 5 = 0
# # non-empty views with sz < 6 = 180
# #nodes in views with sz < 6 = 900
# Remaining #nodes in views with sz < 6 = 0
# # non-empty views with sz < 7 = 136
# #nodes in views with sz < 7 = 816
# Remaining #nodes in views with sz < 7 = 0
# # non-empty views with sz < 8 = 97
# #nodes in views with sz < 8 = 679
# Remaining #nodes in views with sz < 8 = 0
# # non-empty views with sz < 9 = 77
# #nodes in views with sz < 9 = 616
# Remaining #nodes in views with sz < 9 = 0
# # non-empty views with sz < 10 = 78
# #nodes in views with sz < 10 = 702
# Remaining #nodes in views with sz < 10 = 0
# After clustering, max distortion is 6.859170
# ###############
# Took 68.4 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 154 intermediate views
# Ambiguous overlaps checked for 308 intermediate views
# Ambiguous overlaps checked for 462 intermediate views
# Ambiguous overlaps checked for 616 intermediate views
# Ambiguous overlaps checked for 617 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 154 views completed
# Initial alignment of 308 views completed
# Initial alignment of 462 views completed
# Initial alignment of 616 views completed
# error: 0.0005574742484634555
# ###############
# Took 6.9 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.00027702312793361443
# Iteration: 1
# error: 0.0003208256935394458
# Iteration: 2
# error: 0.0003520868206462968
# Iteration: 3
# error: 0.0004012732287562632
# Iteration: 4
# error: 0.0004153445810655274
# Iteration: 5
# error: 0.000442306219952113
# Iteration: 6
# error: 0.0004540472963810124
# Iteration: 7
# error: 0.0004628185750993251
# Iteration: 8
# error: 0.0004945884245444699
# Iteration: 9
# error: 0.0005249267473509209
# Iteration: 10
# error: 0.0005541621450396013
# Iteration: 11
# error: 0.0005888153219388419
# Iteration: 12
# error: 0.0006216481438415597
# Iteration: 13
# error: 0.0006455658272793919
# Iteration: 14
# error: 0.0006891955324633521
# Iteration: 15
# error: 0.0007308172324997717
# Iteration: 16
# error: 0.0007616905544740728
# Iteration: 17
# error: 0.0007706656609896257
# Iteration: 18
# error: 0.0007763974860501735
# Iteration: 19
# error: 0.0007809898980960314
# ###############
# Took 271.4 seconds to refine global embedding.
# ###############
# ###############
# Took 279.8 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'jet', 'LDLE0_jet')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'jet', 'LDLE1_jet')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,0], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'colorcube', 'LDLE0_colorcube')

# %%
# %matplotlib inline
ldle_obj.vis.global_embedding(ldle_obj.y_final, labelsMat[:,1], 'summer',
                             ldle_obj.color_of_pts_on_tear_final, 'colorcube', 'LDLE1_colorcube')
