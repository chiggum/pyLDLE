# %%
# %matplotlib inline

# %%
import sys
sys.path.insert(0,'..')
import pickle

import visualize
import datasets
import ldle
# Uncomment to reload a library
from importlib import reload 
visualize = reload(visualize)
ldle = reload(ldle)
datasets = reload(datasets)
# Out:
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline
# matplotlib.get_backend() =  module://ipykernel.pylab.backend_inline

# %%
save_dir_root = '../data/ldle/double_spherewithhole/'

# %%
X, labelsMat, ddX = datasets.Datasets().spherewithhole()
# Out:
# X.shape =  (9931, 3)

# %% [markdown]
# # LDLE

# %%
ldle_obj = ldle.LDLE(X=X, eta_min=5, max_iter0=20, ddX=ddX,
                     vis = visualize.Visualize(save_dir_root),
                     vis_y_options = {'cmap0':'summer', # for the interior
                                      'cmap1':'jet', # for the tear
                                      'labels':labelsMat[:,0]})

# %%
ldle_obj.fit()
# Out:
# Doubling manifold
# No. of points on the boundary = 34
# Doubled manifold
# A_k, Atilde_k: 0 points processed...
# A_k, Atilde_k: 4957 points processed...
# A_k, Atilde_k: 9914 points processed...
# A_k, Atilde_k: 14871 points processed...
# Atilde_k, Atilde_k: all points processed...
#
# Constructing low distortion local views using LDLE...
# local_param: 0 points processed...
# local_param: 4957 points processed...
# local_param: 9914 points processed...
# local_param: 14871 points processed...
# local_param: all 19828 points processed...
# After iter 1, max distortion is 4.408030
# After iter 2, max distortion is 3.236561
# After iter 3, max distortion is 3.236561
# After iter 4, max distortion is 3.236561
# After iter 5, max distortion is 3.236561
# After iter 6, max distortion is 3.236561
# After iter 7, max distortion is 3.236561
# After iter 8, max distortion is 3.236561
# After iter 9, max distortion is 3.236561
# After iter 10, max distortion is 3.236561
# After iter 11, max distortion is 3.236561
# After iter 12, max distortion is 3.236561
# After iter 13, max distortion is 3.236561
# Max local distortion = 3.1855601075575946
# ###############
# Took 229.9 seconds to perform step 1: construct low distoriton local views
# ###############
#
# Clustering to obtain low distortion intermediate views...
# # non-empty views with sz < 2 = 9931
# #nodes in views with sz < 2 = 9931
# Remaining #nodes in views with sz < 2 = 0
# # non-empty views with sz < 3 = 447
# #nodes in views with sz < 3 = 894
# Remaining #nodes in views with sz < 3 = 0
# # non-empty views with sz < 4 = 339
# #nodes in views with sz < 4 = 1017
# Remaining #nodes in views with sz < 4 = 0
# # non-empty views with sz < 5 = 243
# #nodes in views with sz < 5 = 972
# Remaining #nodes in views with sz < 5 = 0
# After clustering, max distortion is 3.193692
# ###############
# Took 63.2 seconds to perform step 2: construct intermediate views.
# ###############
#
# Initializing parameters and computing initial global embedding...
# Ambiguous overlaps checked for 0 intermediate views
# Ambiguous overlaps checked for 282 intermediate views
# Ambiguous overlaps checked for 564 intermediate views
# Ambiguous overlaps checked for 846 intermediate views
# Ambiguous overlaps checked for 1128 intermediate views
# Ambiguous overlaps checked for 1129 points
# Seq of intermediate views and their predecessors computed.
# Initial alignment of 282 views completed
# Initial alignment of 564 views completed
# Initial alignment of 846 views completed
# Initial alignment of 1128 views completed
# error: 0.0013132281386613969
# ###############
# Took 18.2 seconds to compute initial global embedding.
# ###############
#
# Refining parameters and computing final global embedding...
# Using GPA...
# Iteration: 0
# error: 0.00046127863956056366
# Iteration: 1
# error: 0.000498945529755153
# Iteration: 2
# error: 0.0005203595919520386
# Iteration: 3
# error: 0.0005387830718268335
# Iteration: 4
# error: 0.000568209876205441
# Iteration: 5
# error: 0.0005914822100328879
# Iteration: 6
# error: 0.000607036172541337
# Iteration: 7
# error: 0.0006066965360966656
# Iteration: 8
# error: 0.0006070060807877216
# Iteration: 9
# error: 0.0006215582540862524
# Iteration: 10
# error: 0.0006355599867515607
# Iteration: 11
# error: 0.0006429603680037488
# Iteration: 12
# error: 0.0006686849841175876
# Iteration: 13
# error: 0.0006999529801402409
# Iteration: 14
# error: 0.0007325821353666868
# Iteration: 15
# error: 0.0007473136344849791
# Iteration: 16
# error: 0.0007526931822053574
# Iteration: 17
# error: 0.0007472782125602391
# Iteration: 18
# error: 0.0007378345228629454
# Iteration: 19
# error: 0.0007360460677020966
# ###############
# Took 683.5 seconds to refine global embedding.
# ###############
# ###############
# Took 707.8 seconds to perform step 3: compute global embedding.
# ###############

# %% [markdown]
# # Optionally save for further visualizations using Visualization.ipynb

# %%
save_path = save_dir_root+'/ldle_obj.dat'
with open(save_path, "wb") as f:
    pickle.dump([X, labelsMat, ldle_obj], f)
